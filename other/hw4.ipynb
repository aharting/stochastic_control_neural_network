# %% [markdown]
# Problem 1b

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 10**3
dt = 10**-1
theta = [1]
sample = np.random.normal(loc=0.0, scale=1.0, size=N)
for y in sample:
    new = theta[-1]-dt*2*(theta[-1]-y)
    theta.append(new)
plt.plot(range(N+1),theta)
plt.suptitle("Theta")
plt.xlabel("n")
plt.ylabel("Theta n")
# Out:
# Text(0, 0.5, 'Theta n')

# %% [markdown]
# Problem 2

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib .pyplot as plt
from numpy import linalg as LA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-495a85c87d77> in <module>
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 import numpy as np
#       4 import matplotlib .pyplot as plt
#       5 from numpy import linalg as LA
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
def f(x):
    return np.square(LA.norm(x - 0.5))

# %%
d = 1
N = 100
K = 10
dt = 0.005
M = 40000
T = M*dt
Nbatch = 1
validation_split_ratio = 0.2
EPOCHS = np.int64(M/(N*(1-validation_split_ratio)/Nbatch))
np.random.seed(123)
tf.random.set_seed(124)
x_training = np.random.uniform(-4, 4, size=(N, d))
x_test = np.random.uniform(-4, 4, size=(100 , d))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-460b844e468d> in <module>
#       9 EPOCHS = np.int64(M / (N*(1-validation_split_ratio ) / Nbatch ))
#      10 np.random.seed (123)
# ---> 11 tf.random.set_seed (124)
#      12 x_training = np.random.uniform(-4, 4, size =(N, 1))
#      13 x_test = np.random.uniform(-4, 4, size =(100 , 1))
#
# NameError: name 'tf' is not defined

# %%
y_training = f(x_training)
y_test = f(x_test)
Input_layer = tf.keras.Input(shape=(d,))
Hidden_layer = keras.layers.Dense(units=K, activation ="sigmoid", use_bias=True, kernel_initializer ="random_normal", bias_initializer ="zeros", name="hidden_layer_1")
Output_layer = keras.layers.Dense(units=1, use_bias=False , name="output_layer")
model = keras.Sequential([Input_layer, Hidden_layer, Output_layer ])
optimizer = tf.keras.optimizers.SGD(learning_rate=dt)
model.compile(optimizer =optimizer , loss="mean_squared_error")
history = model.fit(x=x_training , y=y_training , batch_size=Nbatch , epochs=EPOCHS ,validation_split=validation_split_ratio , verbose =1)
model.evaluate(x=x_test , y=y_test , verbose =1)
pts = np.linspace(−4, 4, 300). reshape(−1, 1)
target_fcn_vals = f(pts)
alpha_vals = model(pts)

# %%
plt.figure("Learned function", figsize =(15 , 10))
plt.plot(x_training , y_training , "o", label="Training data")
plt.plot(pts , target_fcn_vals , label="Target function")
plt.plot(pts , alpha_vals , label="alpha")
plt.legend ()
plt.show ()

# %%
plt.figure("Error", figsize =(15 , 10))
plt.semilogy(history.history["loss"], label="Training error")
plt.semilogy(history.history["val_loss"], label="Validation error")
plt.xlabel("Epoch")
plt.ylabel("Mean squared error")
plt.legend ()
plt.grid(True)
plt.show ()

# %%
values = np.linspace(-4, 4, 3)
grid = [values for i in range(2)]
grid
# Out:
# [array([-4.,  0.,  4.]), array([-4.,  0.,  4.])]

# %%
# use broadcasting to create a 2D grid of the values
xx, yy = np.meshgrid(grid)

# stack the xx and yy grids to create a 2D array of (x,y) coordinates
samples = np.column_stack((xx.ravel(), yy.ravel()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-07e3128dec6f> in <module>
#       1 # use broadcasting to create a 2D grid of the values
# ----> 2 xx, yy = np.meshgrid(grid)
#       3
#       4 # stack the xx and yy grids to create a 2D array of (x,y) coordinates
#       5 samples = np.column_stack((xx.ravel(), yy.ravel()))
#
# ValueError: not enough values to unpack (expected 2, got 1)
